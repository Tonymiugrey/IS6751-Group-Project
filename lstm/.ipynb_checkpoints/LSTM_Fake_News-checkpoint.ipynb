# %% [markdown]
# # FAKE NEWS LSTM

# %% [markdown]
# ## Imports

# %%
from argparse import Namespace
import os
import json

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm

# %%
from collections import Counter
import re
import string

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('omw-1.4')
from nltk.corpus import stopwords # remove stopword
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Croya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Croya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Croya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Croya\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## Data Vectorization classes

# %% [markdown]
# ### Vocabulary

# %%
class Vocabulary(object):
    """Class to process text and extract vocabulary for mapping"""

    def __init__(self, token_to_idx=None):
        """
        Args:
            token_to_idx (dict): a pre-existing map of tokens to indices
        """    
        # _token_to_idx for char_vocab:
        #   {'<MASK>': 0, '<UNK>': 1, '<BEGIN>': 2, '<END>': 3, 'T': 4, 'o': 5, 't': 6, 'a': 7, ....., 'Á': 79}
        # _idx_to_token: 
        #   {0:'<MASK>'0, 1:'<UNK>', 2:'<BEGIN>',   3:'<END>',   4:'T',  5:'o',  6:'t',  7:'a',....., 79:'Á'}
            
        # _token_to_idx nationality_vocab: {'Arabic': 0, 'Chinese': 1, ..., 'Vietnamese': 17}
        # _idx_to_token:                   {0:'Arabic',  1:'Chinese', ...,  17:'Vietnamese'}

        if token_to_idx is None:
            token_to_idx = {}
        self._token_to_idx = token_to_idx         
                                                  
        self._idx_to_token = {idx: token 
                              for token, idx in self._token_to_idx.items()}
        
    def add_token(self, token):
        """Update mapping dicts based on the token.

        Args:
            token (str): the item to add into the Vocabulary
        Returns:
            index (int): the integer corresponding to the token
        """
        if token in self._token_to_idx:
            index = self._token_to_idx[token]
        else:
            index = len(self._token_to_idx)
            self._token_to_idx[token] = index
            self._idx_to_token[index] = token
        return index
            
    def lookup_token(self, token):
        """Retrieve the index associated with the token 
        
        Args:
            token (str): the token to look up 
        Returns:
            index (int): the index corresponding to the token
        """
        return self._token_to_idx[token]

    def lookup_index(self, index):
        """Return the token associated with the index
        
        Args: 
            index (int): the index to look up
        Returns:
            token (str): the token corresponding to the index
        Raises:
            KeyError: if the index is not in the Vocabulary
        """
        if index not in self._idx_to_token:
            raise KeyError("the index (%d) is not in the Vocabulary" % index)
        return self._idx_to_token[index]

    def __str__(self):
        return "<Vocabulary(size=%d)>" % len(self)

    def __len__(self):
        return len(self._token_to_idx)

# %%
class SequenceVocabulary(Vocabulary):
    def __init__(self, token_to_idx=None, unk_token="<UNK>",
                 mask_token="<MASK>", begin_seq_token="<BEGIN>",
                 end_seq_token="<END>"):

        super(SequenceVocabulary, self).__init__(token_to_idx)

        self._mask_token = mask_token  # for paddding, e.g., 'McMahan' -> [2, 5, 6, 5, 7, 8, 7, 9, 3, 0, 0, 0, ..., 0]
        self._unk_token = unk_token
        self._begin_seq_token = begin_seq_token
        self._end_seq_token = end_seq_token

        self.mask_index = self.add_token(self._mask_token)           # mask_index is 0
        self.unk_index = self.add_token(self._unk_token)             # unk_index is 1
        self.begin_seq_index = self.add_token(self._begin_seq_token) # begin_seq_index is 2
        self.end_seq_index = self.add_token(self._end_seq_token)     # end_seq_index is 3

    def lookup_token(self, token):
        """Retrieve the index associated with the token 
          or the UNK index if token isn't present.
        
        Args:
            token (str): the token to look up 
        Returns:
            index (int): the index corresponding to the token
        Notes:
            `unk_index` needs to be >=0 (having been added into the Vocabulary) 
              for the UNK functionality 
        """
        if self.unk_index >= 0:
            return self._token_to_idx.get(token, self.unk_index)
        else:
            return self._token_to_idx[token]

# %% [markdown]
# ### Vectorizer

# %%
class NewsVectorizer(object):
    """ The Vectorizer which coordinates the Vocabularies and puts them to use"""   
    def __init__(self, news_vocab, category_vocab):
        self.news_vocab = news_vocab
        self.category_vocab = category_vocab

    def vectorize(self, text, vector_length=-1):
        """
        Args:
            text (str): the string of words separated by a space
            vector_length (int): an argument for forcing the length of index vector
        Returns:
            the vetorized text (numpy.array)
        """        
        indices = [self.news_vocab.begin_seq_index]
        indices.extend(self.news_vocab.lookup_token(token) 
                       for token in text.split(" "))
        indices.append(self.news_vocab.end_seq_index)

        if vector_length < 0:
            vector_length = len(indices)

        out_vector = np.zeros(vector_length, dtype=np.int64)   # SurnameDataset._max_seq_length is 19 in current dataset.      
        out_vector[:len(indices)] = indices
        out_vector[len(indices):] = self.news_vocab.mask_index
        
        """    
        mask_index is 0
        unk_index is 1
        begin_seq_index is 2
        end_seq_index is 3
        
        When surname is "McMahan", M=5,c=6, a=7, h=8, and n=9 
        
        out_vector = [2, 5, 6, 5, 7, 8, 7, 9, 3, 0, 0, 0, ..., 0]
        len(indices) = 9      
        """ 
        #return out_vector, len(indices)
        return out_vector

    @classmethod
    def from_dataframe(cls, news_df, cutoff=25):
        """Instantiate the vectorizer from the dataset dataframe
        Args:
            news_df (pandas.DataFrame): the surnames dataset
        Returns:
            an instance of the NewsVectorizer
        """
        category_vocab = Vocabulary()
        for category in sorted(set(news_df.category)):
            category_vocab.add_token(category)

        word_counts = Counter()
        for text in news_df.text:
            for token in text.split(" "):
                if token not in string.punctuation:
                    word_counts[token] += 1
                    
        news_vocab = SequenceVocabulary()
        for word, word_count in word_counts.items():
            if word_count >= cutoff:
                news_vocab.add_token(word)
        
        return cls(news_vocab, category_vocab)

# %% [markdown]
# ### Dataset

# %%
def text_preprocessing(text):
    text = text.lower() # case folding
    text = re.sub('&\w*\;\w*', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('\n', '', text)
    text = re.sub(r"[^a-z]+", r" ", text) # Regulation, remove special charecters
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    lemmatizer=WordNetLemmatizer()
    # remove stopwords and lemmatization
    result = [lemmatizer.lemmatize(i) for i in tokens if not i in stop_words]
    result = result[:500]
    # bigram
    bigram_result = []
    bigram_list = ngrams(result, 2)
    for word_set in bigram_list:
        for word in word_set:
            bigram_result.append(word)
    return bigram_result

test_str_1 = "This is sentence to test the effect of preprocessing... Yeah~\nCool!fac  feae ge fe ga 🪣🛀🎀 ☏☢︎⏥␘⍎ (>╹ω╹<)喵"
test_str_2 = "Glaxo Settles Paxil 'Suicide Pill' Suit.  NEW YORK (Reuters) - GlaxoSmithKline Plc &lt;A HREF=http://www.investor.reuters.com/FullQuote.aspx?ticker=GSK.L target=/stocks/quickinfo/fullquote""&gt;GSK.L&lt;/A&gt; has agreed  to release all clinical studies of its drugs to settle a  lawsuit that accused it of withholding negative information  about the antidepressant Paxil, the New York Attorney General's  office said on Thursday."
list = text_preprocessing(test_str_2)
' '.join(list)
# Out:
# 'glaxo settle settle paxil paxil suicide suicide pill pill suit suit new new york york reuters reuters glaxosmithkline glaxosmithkline plc plc href href target target stock stock quickinfo quickinfo fullquote fullquote l l agreed agreed release release clinical clinical study study drug drug settle settle lawsuit lawsuit accused accused withholding withholding negative negative information information antidepressant antidepressant paxil paxil new new york york attorney attorney general general office office said said thursday'

# %%
class NewsDataset(Dataset):
    def __init__(self, news_df, vectorizer):
        """
        Args:
            news_df (pandas.DataFrame): the dataset
            vectorizer (SurnameVectorizer): vectorizer instatiated from dataset
        """
        self.news_df = news_df 
        self._vectorizer = vectorizer
        
        # +1 if only using begin_seq, +2 if using both begin and end seq tokens
        measure_len = lambda context: len(context.split(" "))
        self._max_seq_length = max(map(measure_len, news_df.text)) + 2

        self.train_df = self.news_df[self.news_df.split=='train']
        self.train_size = len(self.train_df)

        self.val_df = self.news_df[self.news_df.split=='val']
        self.validation_size = len(self.val_df)

        self.test_df = self.news_df[self.news_df.split=='test']
        self.test_size = len(self.test_df)

        self._lookup_dict = {'train': (self.train_df, self.train_size), 
                             'val': (self.val_df, self.validation_size), 
                             'test': (self.test_df, self.test_size)}

        self.set_split('train')
        
        # Class weights
        class_counts = self.train_df.category.value_counts().to_dict()  
        def sort_key(item):
            return self._vectorizer.category_vocab.lookup_token(item[0]) 
        sorted_counts = sorted(class_counts.items(), key=sort_key)          
        frequencies = [count for _, count in sorted_counts]
        self.class_weights = 1.0 / torch.tensor(frequencies, dtype=torch.float32) 

        
    @classmethod
    def load_dataset_and_make_vectorizer(cls, news_csv):
        """Load dataset and make a new vectorizer from scratch
        
        Args:
            news_csv (str): location of the dataset
        Returns:
            an instance of SurnameDataset
        """
        news_df = pd.read_csv(news_csv)
        for index, text in enumerate(news_df.text):
            processed_list = text_preprocessing(text)
            news_df.text[index] = ' '.join(processed_list)
        train_news_df = news_df[news_df.split=='train']
        return cls(news_df, NewsVectorizer.from_dataframe(train_news_df))
        
    def get_vectorizer(self):
        """ returns the vectorizer """
        return self._vectorizer

    def set_split(self, split="train"):
        self._target_split = split
        self._target_df, self._target_size = self._lookup_dict[split]

    def __len__(self):
        return self._target_size

    def __getitem__(self, index):
        """the primary entry point method for PyTorch datasets
        
        Args:
            index (int): the index to the data point 
        Returns:
            a dictionary holding the data point's:
                features (x_data)
                label (y_target)
                feature length (x_length)
        """
        row = self._target_df.iloc[index]
        
        news_vector = \
            self._vectorizer.vectorize(row.text, self._max_seq_length)
        
        category_index = \
            self._vectorizer.category_vocab.lookup_token(row.category)

        return {'x_data': news_vector, 
                'y_target': category_index} 
    
    def get_num_batches(self, batch_size):
        """Given a batch size, return the number of batches in the dataset
        
        Args:
            batch_size (int)
        Returns:
            number of batches in the dataset
        """
        return len(self) // batch_size   

def generate_batches(dataset, batch_size, shuffle=True,
                     drop_last=True, device="cpu"): 
    """
    A generator function which wraps the PyTorch DataLoader. It will 
      ensure each tensor is on the write device location.
    """
    dataloader = DataLoader(dataset=dataset, batch_size=batch_size,
                            shuffle=shuffle, drop_last=drop_last)

    for data_dict in dataloader:
        out_data_dict = {}
        for name, tensor in data_dict.items():
            out_data_dict[name] = data_dict[name].to(device)
        yield out_data_dict

# %% [markdown]
# ## Model: NewsClassifier

# %%
def column_gather(y_out, x_lengths):
    '''Get a specific vector from each batch datapoint in `y_out`.

    More precisely, iterate over batch row indices, get the vector that's at
    the position indicated by the corresponding value in `x_lengths` at the row
    index.

    Args:
        y_out (torch.FloatTensor, torch.cuda.FloatTensor)
            shape: (batch, sequence, feature)
        x_lengths (torch.LongTensor, torch.cuda.LongTensor)
            shape: (batch,)

    Returns:
        y_out (torch.FloatTensor, torch.cuda.FloatTensor)
            shape: (batch, feature)
    '''
    x_lengths = x_lengths.long().detach().cpu().numpy() - 1   # deduct 1 since the index starts from 0
                                                              # e.g., [9, 6, 11, 9, 7, ...., 12]
    out = []
    for batch_index, column_index in enumerate(x_lengths): # out gets the last hidden vector of each input: (batch, hidden_size)
        out.append(y_out[batch_index, column_index]) # e.g., y_out[0, 9], y_out[1, 6]

    return torch.stack(out)  # (batch, hidden_size*num_directions); E.g., (64, 64*num_direction)

def column_summation(y_out, x_lengths, mode="mean"):
    '''Get a max or mean vector from each batch datapoint in `y_out`.

    More precisely, iterate over batch row indices, get the max or mean vector of all the vectors by 
    the position indicated by the corresponding value in `x_lengths` at the row index.

    Args:
        y_out (torch.FloatTensor, torch.cuda.FloatTensor)
            shape: (batch, sequence, feature)
        x_lengths (torch.LongTensor, torch.cuda.LongTensor)
            shape: (batch,)
        mode: "mean" for mean vector; "max" for max vector

    Returns:
        y_out (torch.FloatTensor, torch.cuda.FloatTensor)
            shape: (batch, feature)
    '''
    x_lengths = x_lengths.long().detach().cpu().numpy() - 1

    out = []
    for batch_index, column_index in enumerate(x_lengths):
        if mode == "mean":
            # replace "pass" with your code to get the mean vector of current batch item from y_out[], and append it to out list.
            pass
        else:
            # replace "pass" with your code to get the max vector of current batch item from y_out[], , and append it to out list.
            pass

    return torch.stack(out)

# %%
class NewsClassifier(nn.Module):
    """ A Classifier with an RNN to extract features and an MLP to classify """
    def __init__(self, embedding_size, num_embeddings, num_classes,
                 rnn_hidden_size, bidirectional=False, batch_first=True, padding_idx=0):
        """
        Args:
            embedding_size (int): The size of the character embeddings
            num_embeddings (int): The number of characters to embed
            num_classes (int): The size of the prediction vector 
                Note: the number of nationalities
            bidirectional (bool): Informs whether bidrectional RNN is used
            rnn_hidden_size (int): The size of the RNN's hidden state
            batch_first (bool): Informs whether the input tensors will 
                have batch or the sequence on the 0th dimension
            padding_idx (int): The index for the tensor padding; 
                see torch.nn.Embedding
        """
        super(NewsClassifier, self).__init__()

        if bidirectional == False:
             self.num_directions = 1
        else:
             self.num_directions = 2
        
        self.emb = nn.Embedding(num_embeddings=num_embeddings,    # E.g., (80, 100)
                                embedding_dim=embedding_size,
                                padding_idx=padding_idx)          # mask_index (padding index) is 0

        #self.rnn = nn.RNN(input_size=embedding_size,              # E.g., 100
        #self.rnn = nn.GRU(input_size=embedding_size,
        self.rnn = nn.LSTM(input_size=embedding_size,
                             hidden_size=rnn_hidden_size,         # E.g., 64
                             batch_first=batch_first, 
                             num_layers = 1,
                             dropout = 0.0, 
                             bidirectional=bidirectional)
        #self.fc1 = nn.Linear(rnn_hidden_size, 128)
        #self.fc2 = nn.Linear(128, 1)
        
        self.fc1 = nn.Linear(in_features=rnn_hidden_size*self.num_directions, out_features=rnn_hidden_size*self.num_directions)
        self.fc2 = nn.Linear(in_features=rnn_hidden_size*self.num_directions,out_features=num_classes)                            
        # for batch norm
        self.bn1 = nn.BatchNorm1d(rnn_hidden_size*self.num_directions) 


    def forward(self, x_in, x_lengths=None, apply_softmax=False):
        """The forward pass of the classifier
        
        Args:
            x_in (torch.Tensor): an input data tensor. 
                x_in.shape should be (batch, input_dim, i.e. seq_size)
            x_lengths (torch.Tensor): the lengths of each sequence in the batch.
                They are used to find the final vector of each sequence: (batch,)
            apply_softmax (bool): a flag for the softmax activation
                should be false if used with the Cross Entropy losses
        Returns:
            the resulting tensor. tensor.shape should be (batch, output_dim)
        """
        x_embedded = self.emb(x_in)    
        
        y_out, _ = self.rnn(x_embedded)  
      
        if x_lengths is not None:       
            y_out = column_gather(y_out, x_lengths) 
        else:
            y_out = y_out[:, -1, :]      
            
        # with batch norm and dropout
        y_out = F.relu(self.bn1(self.fc1(F.dropout(y_out, 0.2, training=self.training))))  # y_out: (64, 64*num_direction)

        
        # with dropout
        y_out = self.fc2(F.dropout(y_out, 0.2, training=self.training))   # y_out: (batch, num_classes) ; (64, 18)

        if apply_softmax:
            y_out = F.softmax(y_out, dim=1)

        return y_out

# %% [markdown]
# ## Settings

# %% [markdown]
# ### general utilities

# %%
def set_seed_everywhere(seed, cuda):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if cuda:
        torch.cuda.manual_seed_all(seed)

def handle_dirs(dirpath):
    if not os.path.exists(dirpath):
        os.makedirs(dirpath)

# %%
def handle_dirs(dirpath):
    if not os.path.exists(dirpath):
        os.makedirs(dirpath)
        
def load_glove_from_file(glove_filepath):
    """
    Load the GloVe embeddings 
    
    Args:
        glove_filepath (str): path to the glove embeddings file 
    Returns:
        word_to_index (dict), embeddings (numpy.ndarary)
    """

    word_to_index = {}
    embeddings = []
    with open(glove_filepath, "r", encoding='utf8') as fp:
        for index, line in enumerate(fp):
            line = line.split(" ") # each line: word num1 num2 ...
            word_to_index[line[0]] = index # word = line[0] 
            embedding_i = np.array([float(val) for val in line[1:]])
            embeddings.append(embedding_i)
    return word_to_index, np.stack(embeddings)

def make_embedding_matrix(glove_filepath, words):
    """
    Create embedding matrix for a specific set of words.
    
    Args:
        glove_filepath (str): file path to the glove embeddigns
        words (list): list of words in the dataset
    """
    word_to_idx, glove_embeddings = load_glove_from_file(glove_filepath)
    embedding_size = glove_embeddings.shape[1]
    
    final_embeddings = np.zeros((len(words), embedding_size))

    for i, word in enumerate(words):
        if word in word_to_idx:
            final_embeddings[i, :] = glove_embeddings[word_to_idx[word]]
        else:
            embedding_i = torch.ones(1, embedding_size)
            torch.nn.init.xavier_uniform_(embedding_i)
            final_embeddings[i, :] = embedding_i

    return final_embeddings

# %%
args = Namespace(
    # Data and path information
    news_csv="../data/processed/fake_or_real_news_with_splits.csv",
    model_state_file="model_LSTM_Fake_News.pth",
    save_dir="../model_storage/Fake_News",
    # Model hyper parameter
    glove_filepath='../data/glove/glove.6B.100d.txt', 
    use_glove=True,
    
    embedding_size=128,
    rnn_hidden_size=256,
    bidirectional=True,
    # Training hyper parameter
    num_epochs=30,
    learning_rate=0.001,
    batch_size=64,
    seed=1337,
    early_stopping_criteria=5,
    # Runtime hyper parameter
    cuda=True,
    catch_keyboard_interrupt=True,
    expand_filepaths_to_save_dir=True,
)


    
# Check CUDA
if not torch.cuda.is_available():
    args.cuda = False

args.device = torch.device("cuda" if args.cuda else "cpu")
    
print("Using CUDA: {}".format(args.cuda))


if args.expand_filepaths_to_save_dir:
    args.model_state_file = os.path.join(args.save_dir, args.model_state_file)
    
# Set seed for reproducibility
set_seed_everywhere(args.seed, args.cuda)

# handle dirs
handle_dirs(args.save_dir)
# Out:
# Using CUDA: True

# %% [markdown]
# ### Initializations

# %%
# create dataset and vectorizer
dataset = NewsDataset.load_dataset_and_make_vectorizer(args.news_csv)

vectorizer = dataset.get_vectorizer()

# Use GloVe or randomly initialized embeddings
if args.use_glove:
    words = vectorizer.news_vocab._token_to_idx.keys()  # 3409 unique words
    embeddings = make_embedding_matrix(glove_filepath=args.glove_filepath,     # embeddings: (3409, 100)
                                       words=words)
    print("Using pre-trained embeddings")
else:
    print("Not using pre-trained embeddings")
    embeddings = None
# Out:
# C:\Users\Croya\AppData\Local\Temp\ipykernel_2620\239385863.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df.text[index] = ' '.join(processed_list)
# Using pre-trained embeddings

# %%
classifier = NewsClassifier(embedding_size=args.embedding_size, 
                               num_embeddings=len(vectorizer.news_vocab),
                               num_classes=len(vectorizer.category_vocab),
                               rnn_hidden_size=args.rnn_hidden_size,
                               padding_idx=vectorizer.news_vocab.mask_index,
                               bidirectional=args.bidirectional)

# %%
print(classifier)
# Out:
# NewsClassifier(
#   (emb): Embedding(9590, 128, padding_idx=0)
#   (rnn): LSTM(128, 256, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=512, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
dataset._max_seq_length # max sequence length
# Out:
# 1000

# %%
vectorizer.news_vocab._token_to_idx
# Out:
# {'<MASK>': 0,
#  '<UNK>': 1,
#  '<BEGIN>': 2,
#  '<END>': 3,
#  'nothing': 4,
#  'good': 5,
#  'come': 6,
#  'election': 7,
#  'posted': 8,
#  'november': 9,
#  'charles': 10,
#  'hugh': 11,
#  'smith': 12,
#  'overwhelming': 13,
#  'consensus': 14,
#  'across': 15,
#  'political': 16,
#  'spectrum': 17,
#  'thing': 18,
#  'go': 19,
#  'like': 20,
#  'country': 21,
#  'deeply': 22,
#  'divided': 23,
#  'every': 24,
#  'institution': 25,
#  'two': 26,
#  'party': 27,
#  'mainstream': 28,
#  'medium': 29,
#  'department': 30,
#  'justice': 31,
#  'cover': 32,
#  'ups': 33,
#  'collusion': 34,
#  'worse': 35,
#  'whomever': 36,
#  'win': 37,
#  'enter': 38,
#  'presidency': 39,
#  'without': 40,
#  'mandate': 41,
#  'nation': 42,
#  'corruption': 43,
#  'require': 44,
#  'hitting': 45,
#  'bottom': 46,
#  'alcoholic': 47,
#  'drug': 48,
#  'incapable': 49,
#  'making': 50,
#  'truly': 51,
#  'positive': 52,
#  'change': 53,
#  'hit': 54,
#  'absolute': 55,
#  'tolerance': 56,
#  'corrupt': 57,
#  'system': 58,
#  'poisoning': 59,
#  'one': 60,
#  'injection': 61,
#  'cash': 62,
#  'pay': 63,
#  'play': 64,
#  'time': 65,
#  'rotten': 66,
#  'core': 67,
#  'politics': 68,
#  'usual': 69,
#  'indeed': 70,
#  'flying': 71,
#  'cliff': 72,
#  'complete': 73,
#  'destruction': 74,
#  'continue': 75,
#  'self': 76,
#  'destructive': 77,
#  'path': 78,
#  'aid': 79,
#  'order': 80,
#  'expanded': 81,
#  'insider': 82,
#  'k': 83,
#  'street': 84,
#  'lobbyist': 85,
#  'army': 86,
#  'well': 87,
#  'paid': 88,
#  'pundit': 89,
#  'academic': 90,
#  'organ': 91,
#  'governance': 92,
#  'big': 93,
#  'money': 94,
#  'private': 95,
#  'sector': 96,
#  'capitalist': 97,
#  'dynasty': 98,
#  'foundation': 99,
#  'way': 100,
#  'anything': 101,
#  'establishment': 102,
#  'politico': 103,
#  'loses': 104,
#  'mere': 105,
#  'existence': 106,
#  'clinton': 107,
#  'trigger': 108,
#  'landslide': 109,
#  'loss': 110,
#  'tie': 111,
#  'candidate': 112,
#  'debate': 113,
#  'question': 114,
#  'etc': 115,
#  'alone': 116,
#  'cause': 117,
#  'colluding': 118,
#  'lose': 119,
#  'refuse': 120,
#  'accept': 121,
#  'donation': 122,
#  'larger': 123,
#  'anyone': 124,
#  'entity': 125,
#  'beat': 126,
#  'goldman': 127,
#  'sachs': 128,
#  'saudi': 129,
#  'prince': 130,
#  'funded': 131,
#  'fund': 132,
#  'costly': 133,
#  'negative': 134,
#  'tv': 135,
#  'advertising': 136,
#  'campaign': 137,
#  'million': 138,
#  'contribution': 139,
#  'et': 140,
#  'al': 141,
#  'get': 142,
#  'point': 143,
#  'citizen': 144,
#  'voter': 145,
#  'stop': 146,
#  'systemic': 147,
#  'promise': 148,
#  'hope': 149,
#  'blitz': 150,
#  'easy': 151,
#  'blame': 152,
#  'law': 153,
#  'corrupted': 154,
#  'ultimately': 155,
#  'responsible': 156,
#  'enabling': 157,
#  'financial': 158,
#  'elite': 159,
#  'view': 160,
#  'msm': 161,
#  'half': 162,
#  'may': 163,
#  'actually': 164,
#  'cast': 165,
#  'mass': 166,
#  'rejection': 167,
#  'highest': 168,
#  'possible': 169,
#  'public': 170,
#  'hand': 171,
#  'wringing': 172,
#  'fortune': 173,
#  'russia': 174,
#  'syria': 175,
#  'blamed': 176,
#  'idlib': 177,
#  'bombing': 178,
#  'hoax': 179,
#  'speaking': 180,
#  'valdai': 181,
#  'international': 182,
#  'discussion': 183,
#  'club': 184,
#  'thursday': 185,
#  'putin': 186,
#  'said': 187,
#  'russian': 188,
#  'patience': 189,
#  'limit': 190,
#  'show': 191,
#  'n': 192,
#  'restraint': 193,
#  'far': 194,
#  'respond': 195,
#  'ed': 196,
#  'partner': 197,
#  'manner': 198,
#  'everything': 199,
#  'explained': 200,
#  'waiting': 201,
#  'given': 202,
#  'endless': 203,
#  'u': 204,
#  'provocation': 205,
#  'refusing': 206,
#  'mutual': 207,
#  'cooperation': 208,
#  'vital': 209,
#  'issue': 210,
#  'rejecting': 211,
#  'normal': 212,
#  'relation': 213,
#  'heading': 214,
#  'inevitably': 215,
#  'war': 216,
#  'unless': 217,
#  'challenged': 218,
#  'stopped': 219,
#  'stupid': 220,
#  'uninformed': 221,
#  'intelligence': 222,
#  'capability': 223,
#  'likely': 224,
#  'match': 225,
#  'america': 226,
#  'know': 227,
#  'eastern': 228,
#  'europe': 229,
#  'elsewhere': 230,
#  'middle': 231,
#  'east': 232,
#  'along': 233,
#  'virtually': 234,
#  'everywhere': 235,
#  'else': 236,
#  'pretending': 237,
#  'logic': 238,
#  'thinking': 239,
#  'washington': 240,
#  'day': 241,
#  'exponentially': 242,
#  'hillary': 243,
#  'succeeds': 244,
#  'obama': 245,
#  'virtual': 246,
#  'certainty': 247,
#  'fair': 248,
#  'foul': 249,
#  'mean': 250,
#  'latter': 251,
#  'theft': 252,
#  'longstanding': 253,
#  'tradition': 254,
#  'showing': 255,
#  'democracy': 256,
#  'pure': 257,
#  'fantasy': 258,
#  'screaming': 259,
#  'deceptive': 260,
#  'western': 261,
#  'headline': 262,
#  'syrian': 263,
#  'school': 264,
#  'province': 265,
#  'occurred': 266,
#  'supported': 267,
#  'terrorist': 268,
#  'attacked': 269,
#  'killing': 270,
#  'least': 271,
#  'six': 272,
#  'child': 273,
#  'many': 274,
#  'others': 275,
#  'exclusive': 276,
#  'rt': 277,
#  'investigation': 278,
#  'determined': 279,
#  'gas': 280,
#  'mine': 281,
#  'landed': 282,
#  'classroom': 283,
#  'launched': 284,
#  'controlled': 285,
#  'aleppo': 286,
#  'yet': 287,
#  'ignoring': 288,
#  'daily': 289,
#  'shelling': 290,
#  'civilian': 291,
#  'government': 292,
#  'part': 293,
#  'city': 294,
#  'long': 295,
#  'internet': 296,
#  'access': 297,
#  'important': 298,
#  'information': 299,
#  'reliable': 300,
#  'independent': 301,
#  'source': 302,
#  'social': 303,
#  'commentator': 304,
#  'rogers': 305,
#  'read': 306,
#  'paper': 307,
#  'ignorance': 308,
#  'reporting': 309,
#  'deplorable': 310,
#  'today': 311,
#  'beyond': 312,
#  'pale': 313,
#  'hard': 314,
#  'waste': 315,
#  'belief': 316,
#  'television': 317,
#  'news': 318,
#  'credible': 319,
#  'reader': 320,
#  'viewer': 321,
#  'listener': 322,
#  'systematically': 323,
#  'lied': 324,
#  'fare': 325,
#  'fit': 326,
#  'print': 327,
#  'broadcast': 328,
#  'editor': 329,
#  'reporter': 330,
#  'noah': 331,
#  'ark': 332,
#  'scam': 333,
#  'artist': 334,
#  'defense': 335,
#  'ministry': 336,
#  'spokesman': 337,
#  'general': 338,
#  'igor': 339,
#  'konashenkov': 340,
#  'called': 341,
#  'video': 342,
#  'footage': 343,
#  'incident': 344,
#  'shown': 345,
#  'fake': 346,
#  'ten': 347,
#  'edited': 348,
#  'fragment': 349,
#  'assembled': 350,
#  'together': 351,
#  'warplane': 352,
#  'area': 353,
#  'attack': 354,
#  'bomb': 355,
#  'existed': 356,
#  'damage': 357,
#  'inconsistent': 358,
#  'wall': 359,
#  'damaged': 360,
#  'ceiling': 361,
#  'desk': 362,
#  'chair': 363,
#  'blast': 364,
#  'would': 365,
#  'destroyed': 366,
#  'severely': 367,
#  'building': 368,
#  'furniture': 369,
#  'inside': 370,
#  'swept': 371,
#  'away': 372,
#  'see': 373,
#  'photo': 374,
#  'drone': 375,
#  'roof': 376,
#  'concealed': 377,
#  'revealed': 378,
#  'set': 379,
#  'record': 380,
#  'straight': 381,
#  'leadership': 382,
#  'fell': 383,
#  'victim': 384,
#  'new': 385,
#  'deception': 386,
#  'qaeda': 387,
#  'affiliated': 388,
#  'white': 389,
#  'helmet': 390,
#  'perhaps': 391,
#  'orchestrated': 392,
#  'happened': 393,
#  'sinister': 394,
#  'anti': 395,
#  'agenda': 396,
#  'submit': 397,
#  'review': 398,
#  'globalization': 399,
#  'failing': 400,
#  'strike': 401,
#  'force': 402,
#  'jon': 403,
#  'begin': 404,
#  'piece': 405,
#  'three': 406,
#  'quote': 407,
#  'work': 408,
#  'progress': 409,
#  'underground': 410,
#  'basic': 411,
#  'principle': 412,
#  'state': 413,
#  'exists': 414,
#  'becomes': 415,
#  'twist': 416,
#  'real': 417,
#  'reach': 418,
#  'mind': 419,
#  'already': 420,
#  'word': 421,
#  'tree': 422,
#  'falling': 423,
#  'forest': 424,
#  'make': 425,
#  'sound': 426,
#  'user': 427,
#  'consumer': 428,
#  'want': 429,
#  'fall': 430,
#  'receives': 431,
#  'audio': 432,
#  'event': 433,
#  'dressed': 434,
#  'thousand': 435,
#  'different': 436,
#  'tends': 437,
#  'quality': 438,
#  'eventually': 439,
#  'person': 440,
#  'problem': 441,
#  'chronic': 442,
#  'liar': 443,
#  'press': 444,
#  'expose': 445,
#  'even': 446,
#  'though': 447,
#  'take': 448,
#  'surprisingly': 449,
#  'small': 450,
#  'push': 451,
#  'whole': 452,
#  'operation': 453,
#  'happening': 454,
#  'right': 455,
#  'front': 456,
#  'eye': 457,
#  'basis': 458,
#  'theater': 459,
#  'director': 460,
#  'producer': 461,
#  'think': 462,
#  'first': 463,
#  'rate': 464,
#  'job': 465,
#  'sadly': 466,
#  'mistaken': 467,
#  'gap': 468,
#  'growing': 469,
#  'outright': 470,
#  'non': 471,
#  'becoming': 472,
#  'apparent': 473,
#  'audience': 474,
#  'fool': 475,
#  'direct': 476,
#  'simply': 477,
#  'people': 478,
#  'sell': 479,
#  'soul': 480,
#  'found': 481,
#  'buyer': 482,
#  'transaction': 483,
#  'contain': 484,
#  'guarantee': 485,
#  'shelf': 486,
#  'life': 487,
#  'expiration': 488,
#  'date': 489,
#  'approaching': 490,
#  'civilization': 491,
#  'petty': 492,
#  'rise': 493,
#  'nice': 494,
#  'plan': 495,
#  'let': 496,
#  'examine': 497,
#  'based': 498,
#  'profiling': 499,
#  'member': 500,
#  'analyzed': 501,
#  'shocking': 502,
#  'expected': 503,
#  'untold': 504,
#  'hour': 505,
#  'spent': 506,
#  'several': 507,
#  'year': 508,
#  'ago': 509,
#  'wrote': 510,
#  'tech': 511,
#  'begun': 512,
#  'since': 513,
#  'jeff': 514,
#  'ceo': 515,
#  'amazon': 516,
#  'bought': 517,
#  'post': 518,
#  'fire': 519,
#  'sale': 520,
#  'genius': 521,
#  'success': 522,
#  'mobile': 523,
#  'device': 524,
#  'multiple': 525,
#  'platform': 526,
#  'digital': 527,
#  'taking': 528,
#  'ad': 529,
#  'interest': 530,
#  'story': 531,
#  'thought': 532,
#  'irrelevant': 533,
#  'seen': 534,
#  'create': 535,
#  'bubble': 536,
#  'cozy': 537,
#  'favorite': 538,
#  'little': 539,
#  'separate': 540,
#  'paradigm': 541,
#  'giant': 542,
#  'apple': 543,
#  'territory': 544,
#  'app': 545,
#  'deliver': 546,
#  'yahoo': 547,
#  'upcoming': 548,
#  'operating': 549,
#  'aim': 550,
#  'primary': 551,
#  'iphone': 552,
#  'say': 553,
#  'follows': 554,
#  'topic': 555,
#  'pull': 556,
#  'relevant': 557,
#  'specific': 558,
#  'journalism': 559,
#  'lab': 560,
#  'awesome': 561,
#  'power': 562,
#  'default': 563,
#  'distribution': 564,
#  'put': 565,
#  'entirely': 566,
#  'league': 567,
#  'hundred': 568,
#  'within': 569,
#  'debut': 570,
#  'translation': 571,
#  'present': 572,
#  'overall': 573,
#  'presentation': 574,
#  'outlet': 575,
#  'layer': 576,
#  'control': 577,
#  'fan': 578,
#  'confirming': 579,
#  'prophet': 580,
#  'neo': 581,
#  'con': 582,
#  'rock': 583,
#  'conservative': 584,
#  'republican': 585,
#  'warm': 586,
#  'heart': 587,
#  'believe': 588,
#  'gridlock': 589,
#  'biggest': 590,
#  'concern': 591,
#  'congress': 592,
#  'done': 593,
#  'got': 594,
#  'moon': 595,
#  'tuned': 596,
#  'gossip': 597,
#  'world': 598,
#  'minute': 599,
#  'idea': 600,
#  'convince': 601,
#  'global': 602,
#  'delivering': 603,
#  'host': 604,
#  'appropriate': 605,
#  'lie': 606,
#  'context': 607,
#  'fringe': 608,
#  'doubtful': 609,
#  'look': 610,
#  'food': 611,
#  'planning': 612,
#  'healthier': 613,
#  'produce': 614,
#  'section': 615,
#  'cheer': 616,
#  'declaring': 617,
#  'temporary': 618,
#  'ban': 619,
#  'toxic': 620,
#  'monsanto': 621,
#  'dow': 622,
#  'experiment': 623,
#  'danger': 624,
#  'roundup': 625,
#  'vaccine': 626,
#  'sorry': 627,
#  'count': 628,
#  'recognized': 629,
#  'demographic': 630,
#  'boy': 631,
#  'involved': 632,
#  'car': 633,
#  'crash': 634,
#  'science': 635,
#  'fiction': 636,
#  'near': 637,
#  'future': 638,
#  'search': 639,
#  'engine': 640,
#  'inquiry': 641,
#  'abc': 642,
#  'national': 643,
#  'rating': 644,
#  'giving': 645,
#  'spending': 646,
#  'le': 647,
#  'business': 648,
#  'desperately': 649,
#  'looking': 650,
#  'treating': 651,
#  'construct': 652,
#  'preference': 653,
#  'answer': 654,
#  'mr': 655,
#  'x': 656,
#  'studied': 657,
#  'live': 658,
#  'special': 659,
#  'brand': 660,
#  'truth': 661,
#  'hello': 662,
#  'outlook': 663,
#  'introduce': 664,
#  'button': 665,
#  'delete': 666,
#  'email': 667,
#  'en': 668,
#  'masse': 669,
#  'tuesday': 670,
#  'announced': 671,
#  'next': 672,
#  'version': 673,
#  'popular': 674,
#  'software': 675,
#  'include': 676,
#  'function': 677,
#  'quickly': 678,
#  'computer': 679,
#  'head': 680,
#  'product': 681,
#  'development': 682,
#  'simon': 683,
#  'williams': 684,
#  'fbi': 685,
#  'investigating': 686,
#  'need': 687,
#  'quick': 688,
#  'click': 689,
#  'instantly': 690,
#  'remove': 691,
#  'pc': 692,
#  'useful': 693,
#  'suddenly': 694,
#  'find': 695,
#  'bit': 696,
#  'exchange': 697,
#  'girl': 698,
#  'account': 699,
#  'felt': 700,
#  'chemistry': 701,
#  'took': 702,
#  'grave': 703,
#  'dismissed': 704,
#  'sexual': 705,
#  'harassment': 706,
#  'everyday': 707,
#  'sort': 708,
#  'situation': 709,
#  'office': 710,
#  'suite': 711,
#  'due': 712,
#  'released': 713,
#  'reportedly': 714,
#  'inspired': 715,
#  'update': 716,
#  'continued': 717,
#  'routinely': 718,
#  'forget': 719,
#  'use': 720,
#  'adding': 721,
#  'bill': 722,
#  'simultaneously': 723,
#  'close': 724,
#  'window': 725,
#  'history': 726,
#  'protect': 727,
#  'wife': 728,
#  'ever': 729,
#  'knowing': 730,
#  'monica': 731,
#  'lewinsky': 732,
#  'case': 733,
#  'regular': 734,
#  'prevent': 735,
#  'spouse': 736,
#  'finding': 737,
#  'whatever': 738,
#  'return': 739,
#  'early': 740,
#  'catch': 741,
#  'mid': 742,
#  'pleasure': 743,
#  'customer': 744,
#  'minimize': 745,
#  'maximize': 746,
#  'icon': 747,
#  'top': 748,
#  'thereby': 749,
#  'saving': 750,
#  'attempting': 751,
#  'conceal': 752,
#  'significant': 753,
#  'approach': 754,
#  'industry': 755,
#  'expert': 756,
#  'expecting': 757,
#  'high': 758,
#  'best': 759,
#  'newsthump': 760,
#  'mailbox': 761,
#  'friday': 762,
#  'free': 763,
#  'currently': 764,
#  'remember': 765,
#  'talk': 766,
#  'standing': 767,
#  'donate': 768,
#  'dan': 769,
#  'treaty': 770,
#  'camp': 771,
#  'confrontation': 772,
#  'militarized': 773,
#  'police': 774,
#  'afternoon': 775,
#  'adam': 776,
#  'alexander': 777,
#  'kelly': 778,
#  'hayes': 779,
#  'org': 780,
#  'personal': 781,
#  'indigenous': 782,
#  'woman': 783,
#  'analysis': 784,
#  'friend': 785,
#  'shared': 786,
#  'obviously': 787,
#  'speak': 788,
#  'everyone': 789,
#  'native': 790,
#  'perspective': 791,
#  'diverse': 792,
#  'conviction': 793,
#  'hold': 794,
#  'strong': 795,
#  'watch': 796,
#  'pride': 797,
#  'worry': 798,
#  'feel': 799,
#  'communication': 800,
#  'might': 801,
#  'imagine': 802,
#  'much': 803,
#  'pretty': 804,
#  'stay': 805,
#  'touch': 806,
#  'asked': 807,
#  'wanted': 808,
#  'convey': 809,
#  'maintaining': 810,
#  'limited': 811,
#  'presence': 812,
#  'following': 813,
#  'effort': 814,
#  'corresponding': 815,
#  'crucial': 816,
#  'recognize': 817,
#  'ongoing': 818,
#  'struggle': 819,
#  'colonial': 820,
#  'violence': 821,
#  'nodapl': 822,
#  'erased': 823,
#  'active': 824,
#  'contact': 825,
#  'waged': 826,
#  'survive': 827,
#  'condition': 828,
#  'society': 829,
#  'gone': 830,
#  'largely': 831,
#  'supremacy': 832,
#  'land': 833,
#  'pushed': 834,
#  'consciousness': 835,
#  'fact': 836,
#  'killed': 837,
#  'enforcement': 838,
#  'group': 839,
#  'speaks': 840,
#  'literally': 841,
#  'numerous': 842,
#  'perpetrated': 843,
#  'motif': 844,
#  'intention': 845,
#  'example': 846,
#  'structural': 847,
#  'whereas': 848,
#  'matter': 849,
#  'construction': 850,
#  'deadly': 851,
#  'mechanism': 852,
#  'created': 853,
#  'greed': 854,
#  'driven': 855,
#  'regard': 856,
#  'always': 857,
#  'die': 858,
#  'died': 859,
#  'sake': 860,
#  'expansion': 861,
#  'wealth': 862,
#  'maintenance': 863,
#  'harm': 864,
#  'committed': 865,
#  'book': 866,
#  'american': 867,
#  'exceptionalism': 868,
#  'also': 869,
#  'sustain': 870,
#  'comfort': 871,
#  'benefit': 872,
#  'kept': 873,
#  'sight': 874,
#  'easily': 875,
#  'forgotten': 876,
#  'directly': 877,
#  'impacted': 878,
#  'clear': 879,
#  'rare': 880,
#  'moment': 881,
#  'bear': 882,
#  'witness': 883,
#  'obvious': 884,
#  'fighting': 885,
#  'surviving': 886,
#  'reality': 887,
#  'rarely': 888,
#  'acknowledged': 889,
#  'freedom': 890,
#  'frequently': 891,
#  'intersection': 892,
#  'bearing': 893,
#  'historic': 894,
#  'dialogue': 895,
#  'around': 896,
#  'become': 897,
#  'extremely': 898,
#  'climate': 899,
#  'oriented': 900,
#  'yes': 901,
#  'undeniable': 902,
#  'fight': 903,
#  'combat': 904,
#  'fully': 905,
#  'humanity': 906,
#  'risk': 907,
#  'extinction': 908,
#  'whether': 909,
#  'realize': 910,
#  'focusing': 911,
#  'exclusively': 912,
#  'respective': 913,
#  'sometimes': 914,
#  'journey': 915,
#  'outside': 916,
#  'bound': 917,
#  'discussing': 918,
#  'started': 919,
#  'place': 920,
#  'naming': 921,
#  'defend': 922,
#  'water': 923,
#  'natural': 924,
#  'community': 925,
#  'broad': 926,
#  'sense': 927,
#  'center': 928,
#  'conversation': 929,
#  'often': 930,
#  'reduced': 931,
#  'staging': 932,
#  'ground': 933,
#  'messaging': 934,
#  'ngo': 935,
#  'talking': 936,
#  'deserve': 937,
#  'worth': 938,
#  'defending': 939,
#  'affect': 940,
#  'please': 941,
#  'acknowledging': 942,
#  'pipeline': 943,
#  'impact': 944,
#  'remind': 945,
#  'struggling': 946,
#  'engage': 947,
#  'concrete': 948,
#  'connection': 949,
#  'jumping': 950,
#  'discus': 951,
#  'ally': 952,
#  'accomplice': 953,
#  'alongside': 954,
#  'value': 955,
#  'addition': 956,
#  'continent': 957,
#  'survived': 958,
#  'genocide': 959,
#  'born': 960,
#  'victory': 961,
#  'colonialism': 962,
#  'named': 963,
#  'centered': 964,
#  'courtesy': 965,
#  'afforded': 966,
#  'message': 967,
#  'condemnation': 968,
#  'ask': 969,
#  'asking': 970,
#  'help': 971,
#  'ensure': 972,
#  'policy': 973,
#  'happen': 974,
#  'enough': 975,
#  'fewer': 976,
#  'various': 977,
#  'form': 978,
#  'acting': 979,
#  'solidarity': 980,
#  'deserved': 981,
#  'living': 982,
#  'protector': 983,
#  'warrior': 984,
#  'earned': 985,
#  'robin': 986,
#  'robert': 987,
#  'dying': 988,
#  'cancer': 989,
#  'familiar': 990,
#  'voice': 991,
#  'came': 992,
#  'nurse': 993,
#  'brought': 994,
#  'back': 995,
#  'share': 996,
#  'twitter': 997,
#  'losing': 998,
#  'mother': 999,
#  ...}

# %%
vectorizer.category_vocab._token_to_idx
# Out:
# {'FAKE': 0, 'REAL': 1}

# %% [markdown]
# ## Training Routine

# %% [markdown]
# ### Helper functions

# %%
def make_train_state(args):
    return {'stop_early': False,
            'early_stopping_step': 0,
            'early_stopping_best_val': 1e8,
            'learning_rate': args.learning_rate,
            'epoch_index': 0,
            'train_loss': [],
            'train_acc': [],
            'val_loss': [],
            'val_acc': [],
            'test_loss': -1,
            'test_acc': -1,
            'model_filename': args.model_state_file}


def update_train_state(args, model, train_state):
    """Handle the training state updates.

    Components:
     - Early Stopping: Prevent overfitting.
     - Model Checkpoint: Model is saved if the model is better
    
    :param args: main arguments
    :param model: model to train
    :param train_state: a dictionary representing the training state values
    :returns:
        a new train_state
    """

    # Save one model at least
    if train_state['epoch_index'] == 0:
        torch.save(model.state_dict(), train_state['model_filename'])
        train_state['stop_early'] = False

    # Save model if performance improved
    elif train_state['epoch_index'] >= 1:
        loss_tm1, loss_t = train_state['val_loss'][-2:]
         
        # If loss worsened
        #if loss_t >= loss_tm1:
        if loss_t >= train_state['early_stopping_best_val']:
            # Update step
            train_state['early_stopping_step'] += 1
        # Loss decreased
        else:
            # Save the best model
            if loss_t < train_state['early_stopping_best_val']:
                torch.save(model.state_dict(), train_state['model_filename'])
                train_state['early_stopping_best_val'] = loss_t

            # Reset early stopping step
            train_state['early_stopping_step'] = 0

        # Stop early ?
        train_state['stop_early'] = \
            train_state['early_stopping_step'] >= args.early_stopping_criteria

    return train_state


def compute_accuracy(y_pred, y_target):
    _, y_pred_indices = y_pred.max(dim=1)
    n_correct = torch.eq(y_pred_indices, y_target).sum().item()
    return n_correct / len(y_pred_indices) * 100

# %% [markdown]
# ### Training loop

# %%
classifier = classifier.to(args.device)
dataset.class_weights = dataset.class_weights.to(args.device)
    
loss_func = nn.CrossEntropyLoss(dataset.class_weights)
optimizer = optim.Adam(classifier.parameters(), lr=args.learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=0.1, patience=10)

train_state = make_train_state(args)

epoch_bar = tqdm(desc='training routine', total=args.num_epochs, position=0)

dataset.set_split('train')
train_bar = tqdm(desc='split=train', total=dataset.get_num_batches(args.batch_size), position=1, leave=True)

dataset.set_split('val')
val_bar = tqdm(desc='split=val', total=dataset.get_num_batches(args.batch_size), position=1, leave=True)

try:
    for epoch_index in range(args.num_epochs):
        train_state['epoch_index'] = epoch_index

        # Iterate over training dataset

        # setup: batch generator, set loss and acc to 0, set train mode on
        dataset.set_split('train')
        batch_generator = generate_batches(dataset, 
                                           batch_size=args.batch_size, 
                                           device=args.device)
        running_loss = 0.0
        running_acc = 0.0
        classifier.train()

        for batch_index, batch_dict in enumerate(batch_generator):
            # the training routine is these 5 steps:

            # --------------------------------------    
            # step 1. zero the gradients
            optimizer.zero_grad()

            # step 2. compute the output
            y_pred = classifier(batch_dict['x_data'])  
            
            # step 3. compute the loss
            loss = loss_func(y_pred, batch_dict['y_target'])
    
            running_loss += (loss.item() - running_loss) / (batch_index + 1)

            # step 4. use loss to produce gradients
            loss.backward()

            # step 5. use optimizer to take gradient step
            optimizer.step()
            # -----------------------------------------
            # compute the accuracy
            acc_t = compute_accuracy(y_pred, batch_dict['y_target'])
            running_acc += (acc_t - running_acc) / (batch_index + 1)

            # update bar
            train_bar.set_postfix(loss=running_loss, acc=running_acc, epoch=epoch_index)
            train_bar.update()

        train_state['train_loss'].append(running_loss)
        train_state['train_acc'].append(running_acc)

        # Iterate over val dataset

        # setup: batch generator, set loss and acc to 0; set eval mode on

        dataset.set_split('val')
        batch_generator = generate_batches(dataset, 
                                           batch_size=args.batch_size, 
                                           device=args.device)
        running_loss = 0.
        running_acc = 0.
        classifier.eval()

        for batch_index, batch_dict in enumerate(batch_generator):
            # compute the output
            y_pred = classifier(batch_dict['x_data'])

            # step 3. compute the loss
            loss = loss_func(y_pred, batch_dict['y_target'])
            running_loss += (loss.item() - running_loss) / (batch_index + 1)

            # compute the accuracy
            acc_t = compute_accuracy(y_pred, batch_dict['y_target'])
            running_acc += (acc_t - running_acc) / (batch_index + 1)
            val_bar.set_postfix(loss=running_loss, acc=running_acc, epoch=epoch_index)
            val_bar.update()

        train_state['val_loss'].append(running_loss)
        train_state['val_acc'].append(running_acc)

        train_state = update_train_state(args=args, model=classifier, 
                                         train_state=train_state)


        scheduler.step(train_state['val_loss'][-1])

        train_bar.n = 1
        val_bar.n = 1
        epoch_bar.update()

        if train_state['stop_early']:
            break
            
except KeyboardInterrupt:
    print("Exiting loop")
# Out:
# training routine:   0%|          | 0/30 [00:00<?, ?it/s]
# split=train:   0%|          | 0/69 [00:00<?, ?it/s]
# split=val:   0%|          | 0/14 [00:00<?, ?it/s]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

acc = train_state['train_acc']
val_acc = train_state['val_acc']
loss = train_state['train_loss']
val_loss = train_state['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# compute the loss & accuracy on the test set using the best available model

classifier.load_state_dict(torch.load(train_state['model_filename'])) # load the best model

classifier = classifier.to(args.device)
dataset.class_weights = dataset.class_weights.to(args.device)
loss_func = nn.CrossEntropyLoss(dataset.class_weights)

dataset.set_split('test')
batch_generator = generate_batches(dataset, 
                                   batch_size=args.batch_size, 
                                   device=args.device)
running_loss = 0.
running_acc = 0.
classifier.eval()

y_pred_list = []         # store predicted values for confusion matrix
y_category_list = []  # ground truth value

for batch_index, batch_dict in enumerate(batch_generator):
    # compute the output
    y_pred =  classifier(batch_dict['x_data'])
    
    # store predicted values and ground truth values for calculating confusion matrix
    y_pred_list.extend(y_pred.max(dim=1)[1].cpu().numpy())
    y_category_list.extend(batch_dict['y_target'].cpu().numpy())
    
    # compute the loss
    loss = loss_func(y_pred, batch_dict['y_target'])
    loss_t = loss.item()
    running_loss += (loss_t - running_loss) / (batch_index + 1)

    # compute the accuracy
    acc_t = compute_accuracy(y_pred, batch_dict['y_target'])
    running_acc += (acc_t - running_acc) / (batch_index + 1)

train_state['test_loss'] = running_loss
train_state['test_acc'] = running_acc

# %%
print("Test loss: {};".format(train_state['test_loss']))
print("Test Accuracy: {}".format(train_state['test_acc']))
# Out:
# Test loss: 0.6306236599172864;
# Test Accuracy: 66.18303571428571

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
category_classes = []
for i in range(len(dataset._vectorizer.category_vocab)):
    category_classes.append(dataset._vectorizer.category_vocab.lookup_index(i))
print(category_classes)
# Out:
# ['FAKE', 'REAL']

# %%
import pandas as pd

cm = confusion_matrix(y_category_list, y_pred_list)
cm_df = pd.DataFrame(cm.T, index=category_classes, columns=category_classes)
cm_df.index.name = 'Predicted'
cm_df.columns.name = 'True'
print(cm_df)
# Out:
# True       FAKE  REAL
# Predicted
# FAKE        285   139
# REAL        164   308

# %%
print(classification_report(y_category_list, y_pred_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.63      0.65       449
#            1       0.65      0.69      0.67       447
#
#     accuracy                           0.66       896
#    macro avg       0.66      0.66      0.66       896
# weighted avg       0.66      0.66      0.66       896

# %% [markdown]
# ### Inference

# %%
# Preprocess the reviews
def preprocess_text(text):
    text = ' '.join(word.lower() for word in text.split(" "))
    text = re.sub(r"([.,!?])", r" \1 ", text)
    text = re.sub(r"[^a-zA-Z.,!?]+", r" ", text)
    return text

# %%
def predict_category(title, classifier, vectorizer, max_length):
    """Predict a News category for a new title
    
    Args:
        title (str): a raw title string
        classifier (NewsClassifier): an instance of the trained classifier
        vectorizer (NewsVectorizer): the corresponding vectorizer
        max_length (int): the max sequence length
            Note: CNNs are sensitive to the input data tensor size. 
                  This ensures to keep it the same size as the training data
    """
    title = preprocess_text(title)
    vectorized_title = \
        torch.tensor(vectorizer.vectorize(title, vector_length=max_length))
    result = classifier(vectorized_title.unsqueeze(0))
    probability_values, indices = result.max(dim=1)
    predicted_category = vectorizer.category_vocab.lookup_index(indices.item())

    return {'category': predicted_category, 
            'probability': probability_values.item()}

# %%
def get_samples():
    samples = {}
    for cat in dataset.val_df.category.unique():
        samples[cat] = dataset.val_df.text[dataset.val_df.category==cat].tolist()[:5]
    return samples

val_samples = get_samples() # first 5 titles of each category from validation dataset

# %%
#title = input("Enter a news title to classify: ")
classifier = classifier.to("cpu")

for truth, sample_group in val_samples.items():
    print(f"True Category: {truth}")
    print("="*30)
    for sample in sample_group:
        prediction = predict_category(sample, classifier, 
                                      vectorizer, dataset._max_seq_length)
        print("Prediction: {} (p={:0.2f})".format(prediction['category'],
                                                  prediction['probability']))
        print("\t + Sample: {}".format(sample))
    print("-"*30 + "\n")
# Out:
# True Category: FAKE
# ==============================
# Prediction: FAKE (p=0.24)
# 	 + Sample: hillary clinton clinton postapocalyptic postapocalyptic hellscape hellscape plan plan hillary hillary clinton clinton postapocalyptic postapocalyptic hellscape hellscape plan plan important important avoid avoid age age peace peace hillary hillary clinton clinton postapocalyptic postapocalyptic hellscape hellscape plan plan b b look look email email even even com com wrong wrong comdingdangaramaramaflimflam comdingdangaramaramaflimflam mail mail question question comment comment site site godlike godlike production production glp glp registered registered trademark trademark zero zero point point ltd ltd godlike godlike website website design design copyright copyright godlikeproductions godlikeproductions com com page page generated generated query
# Prediction: REAL (p=0.71)
# 	 + Sample: russophobia war war party party propaganda propaganda information information russophobia russophobia war war party party propagandathe propagandathe world world reactionary reactionary regime regime head head chopping chopping terror terror sponsoring sponsoring saudi saudi arabian arabian kleptocracy kleptocracy awarded awarded chair chair un un human human right right council council russia russia kicked kicked travesty travesty engineered engineered superpower superpower lie lie punish punish moscow moscow resisting resisting u u led led war war sectarian sectarian massacre massacre regime regime change change syria syria war war party party march march cheer cheer corporate corporate medium medium hillary hillary even even elected elected yet yet margaret margaret kimberley kimberley attempt attempt stop stop fighting fighting rejected rejected u u nato nato sealed sealed fate fate syrian syrian people people november november information information clearing clearing house house bar bar russia russia invade invade iraq iraq kill kill one one million million people people russia russia greater greater percentage percentage population population behind behind bar bar country country world world russia russia occupy occupy haiti haiti kidnapping kidnapping president president russian russian police police allowed allowed shoot shoot child child death death without without fear fear repercussion repercussion russia russia entering entering th th year year terror terror war war people people somalia somalia crime crime take take place place direction direction united united state state yet yet full full force force propaganda propaganda influence influence world world opinion opinion directed directed russia russia whatever whatever shortcoming shortcoming hold hold candle candle america america violating violating human human right right danger danger presented presented hillary hillary clinton clinton presidency presidency overstated overstated war war party party steadily steadily working working towards towards goal goal defies defies logic logic risk risk life life earth earth regime regime change change modus modus operandi operandi hope hope make make reality reality russia russia nearly nearly every every claim claim russian russian evil evil lie lie ruse ruse meant meant put put american american fighting fighting mood mood lose lose fear fear nuclear nuclear conflagration conflagration clear clear clinton clinton rest rest would would warrior warrior actually actually realize realize risking risking mushroom mushroom cloud cloud perhaps perhaps believe believe vladimir vladimir putin putin easily easily pushed pushed around around evidence evidence point point contrary contrary unproven unproven allegation allegation interference interference presidential presidential election election casting casting blame blame russia russia sole sole cause cause suffering suffering syria syria meant meant desensitize desensitize public public age age old old ploy ploy make make war war acceptable acceptable deemed deemed necessity necessity usual usual suspect suspect helping helping eagerly eagerly corporate corporate medium medium led led newspaper newspaper like like new new york york time time washington washington post post front front center center pushing pushing tale tale russian russian villainy villainy human human right right watch watch organization organization care care nothing nothing abuse abuse committed committed united united state state ally ally also also playing playing usual usual role role choosing choosing next next regime regime change change victim victim russia russia lost lost seat seat united united nation nation human human right right council council part part american american pressure pressure public public relation relation assistance assistance human human right right industrial industrial complex complex unhrc unhrc chaired chaired saudi saudi arabia arabia saudi saudi arabia arabi ...
# Prediction: FAKE (p=0.24)
# 	 + Sample: world champion champion boxer boxer manny manny pacquiao pacquiao build build home home poor poor filipino filipino earning earning million million fighting fighting floyd floyd mayweather mayweather boxer boxer politician politician used used portion portion earnings earnings construct construct home home poor poor family family hometown hometown manny manny pacquiao pacquiao world world class class athlete athlete filipino filipino politician politician compassionate compassionate activist activist paid paid home home built built help help underprivileged underprivileged family family hometown hometown via via anonews anonews earlier earlier year year pacquiao pacquiao proclaimed proclaimed good good deed deed facebook facebook happy happy giving giving house house free free constituent constituent sarangani sarangani province province pocket pocket thousand thousand family family beneficiary beneficiary star star report report born born christian christian inspired inspired help help poor poor family family duking duking floyd floyd mayweather mayweather though though lost lost boxing boxing match match still still earned earned million million dollar dollar fight fight century century felt felt duty duty give give back back wrote wrote faithful faithful steward steward god god grace grace various various form form use use whatever whatever gift gift received received serve serve others others still still building building always always believe believe bible bible say say offer offer hospitality hospitality one one another another without without grumbling grumbling act act compassion compassion could could nothing nothing calculated calculated political political move move nonetheless nonetheless family family secure secure living living space space thanks thanks senator senator generosity generosity believe believe worth worth celebrating
# Prediction: FAKE (p=0.24)
# 	 + Sample: hillary era era coming coming worry worry photo photo veni veni cc cc trust trust one one noticed noticed rural rural area area economically economically distressed distressed neighborhood neighborhood town town city city lawn lawn sign sign donald donald trump trump everywhere everywhere hillary hillary sign sign rarer rarer tesla tesla maseratis maseratis think think understand understand trump trump sign sign cry cry defiance defiance hillary hillary supporter supporter harder harder figure figure suspect suspect would would soon soon advertise advertise intention intention november november even even think think way way stop stop trump trump understand understand voting voting hillary hillary embarrassing embarrassing lawn lawn sign sign apart apart evidence evidence trump trump kaput kaput overwhelming overwhelming seems seems finally finally done done campaign campaign extent extent even even diehard diehard anti anti trump trump fear fear monger monger concede concede inevitability inevitability clinton clinton return return white white house house trump trump campaign campaign life life support support week week pussy pussy grabbing grabbing tape tape surfaced surfaced followed followed seemingly seemingly endless endless stream stream woman woman dozen dozen already already accusing accusing donald donald groping groping worse worse third third debate debate trump trump announced announced would would wait wait see see accepting accepting legitimacy legitimacy clinton clinton victory victory seems seems final final straw straw bona bona fide fide deplorables deplorables writing writing wall wall hillary hillary win win surely surely sun sun rise rise tomorrow tomorrow well well quite quite almost almost reason reason rejoice rejoice victory victory trump trump defeat defeat even even obvious obvious seems seems hillary hillary probably probably lesser lesser evil evil thing thing considered considered trump trump likely likely le le dangerous dangerous two two man man adolescent adolescent septuagenarian septuagenarian body body tendency tendency act act least least russophobe russophobe neocon neocon humanitarian humanitarian intervener intervener intent intent regime regime change change country country resist resist american american domination domination would would include include usual usual victim victim country country incapable incapable harming harming united united state state militarily militarily russia russia china china well well relevant relevant supposed supposed lesser lesser evil evil committed committed neoliberal neoliberal wall wall street street toady toady trump trump crooked crooked hillary hillary taunt taunt hit hit target target often often consideration consideration others others like like cause cause concern concern fine fine lesser lesser evil evil voting voting general general think think threshold threshold beneath beneath lesser lesser evil evil consideration consideration apply apply need need agonize agonize issue issue however however case case trump trump became became republican republican nominee nominee lesser lesser evil evil argument argument became became moot moot would would still still case case even even voter voter quite quite willfully willfully blind blind danger danger inherent inherent clinton clinton determination determination maintain maintain american american world world domination domination mean mean necessary necessary fondness fondness military military solution solution lesser lesser evil evil consideration consideration irrelevant irrelevant trump trump always always bound bound lose lose democrat democrat even even pressing pressing point point corollary corollary anti anti trump trump hysteria hysteria distraction distraction day day one one recently recently month month ago ago hardly hardly anyone anyone agreed agreed dollar dollar every every time time taken taken task task seeing seeing parallel parallel trump trump phenomenon phenomeno ...
# Prediction: REAL (p=0.50)
# 	 + Sample: connect series series webinar webinar oct oct financial financial market market news news cover cover dominating dominating theme theme market market share share pattern pattern analysis analysis perspective perspective empower empower member member make make better better investment investment decision
# ------------------------------
#
# True Category: REAL
# ==============================
# Prediction: FAKE (p=0.24)
# 	 + Sample: common core core quietly quietly war war argentine argentine president president mauricio mauricio macri macri office office rebutting rebutting report report argentinian argentinian journalist journalist set set wave wave american american medium
# Prediction: REAL (p=1.01)
# 	 + Sample: u face face call call walk walk away away iran iran talk talk leading leading republican republican critic critic iranian iranian nuclear nuclear talk talk calling calling u u walk walk away away table table negotiator negotiator missed missed key key deadline deadline lawmaker lawmaker joined joined voicing voicing concern concern iran iran could could extract extract critical critical final final hour hour concession concession scramble scramble salvage salvage agreement agreement negotiation negotiation resumed resumed switzerland switzerland wednesday wednesday almost almost immediately immediately beset beset competing competing claim claim hour hour diplomat diplomat abandoned abandoned march march deadline deadline reach reach outline outline deal deal agreed agreed press press latest latest round round hit hit week week mark mark three three six six foreign foreign minister minister involved involved left left talk talk prospect prospect agreement agreement remaining remaining uncertain uncertain amid amid confusion confusion sen sen tom tom cotton cotton r r ark ark told told fox fox news news concerned concerned framework framework deal deal could could allow allow iran iran keep keep uranium uranium stockpile stockpile continue continue enrich enrich uranium uranium underground underground bunker bunker willing willing walk walk away away table table reapply reapply leverage leverage iran iran cotton cotton said said fact fact willing willing still still sitting sitting switzerland switzerland negotiating negotiating three three negotiating negotiating partner partner already already left left demonstrates demonstrates iran iran continue continue demand demand dangerous dangerous concession concession west west speaking speaking msnbc msnbc former former democratic democratic presidential presidential candidate candidate howard howard dean dean seemed seemed agree agree said said president president obama obama right right seek seek deal deal might might time time step step away away table table make make clear clear u u backing backing key key position position including including iran iran uranium uranium stockpile stockpile pace pace sanction sanction relief relief worried worried dean dean said said rep rep martha martha mcsally mcsally r r ariz ariz also also told told fox fox news news potentially potentially nuclear nuclear infrastructure infrastructure added added know know exactly exactly behind behind closed closed door door despite despite side side agreeing agreeing blow blow deadline deadline pursuit pursuit rough rough agreement agreement even even white white house house threatened threatened abandon abandon talk talk iran iran budge budge unwilling unwilling make make kind kind commitment commitment give give u u assurance assurance u u mean mean united united state state mean mean international international community community walk walk away away negotiating negotiating table table consider consider option option may may available available u u certainly certainly possibility possibility could could happen happen white white house house press press secretary secretary josh josh earnest earnest said said tuesday tuesday earnest earnest indicated indicated wednesday wednesday still still option option called called scenario scenario hypothetical hypothetical talk talk making making progress progress said said talk talk continue continue productive productive yet yet received received specific specific tangible tangible commitment commitment international international community community require require tuesday tuesday negotiator negotiator trying trying agree agree simply simply joint joint statement statement could could justify justify talk talk continuing continuing final final june june deadline deadline iran iran deputy deputy foreign foreign minister minister abbas abbas araghchi araghchi told told reporter reporter side side make make progress progress text text joint joint statem ...
# Prediction: FAKE (p=0.24)
# 	 + Sample: gun control control becomes becomes litmus litmus test test democratic democratic primary primary move move would would make make easier easier trump trump administration administration demolish demolish exchange
# Prediction: FAKE (p=0.24)
# 	 + Sample: house gop gop budget budget gimmick gimmick six six men men green green tie tie took took stage stage house house television television studio studio tuesday tuesday house house budget budget committee committee chairman chairman tom tom price price slight slight leprechaun leprechaun man man silver silver hair hair dark dark eyebrow eyebrow approached approached microphone microphone good good mor mor top top mornin mornin ya ya price price announced announced happy happy st st patrick patrick day day altogether altogether fitting fitting republican republican rolled rolled budget budget festival festival inebriation inebriation honor honor man man magically magically apocryphally apocryphally banished banished snake snake ireland ireland republican republican done done budget budget le le fantastic fantastic employed employed lucky lucky charm charm mystical mystical pot pot gold gold make make appear appear sober sober balancing balancing budget budget actually actually rely rely gimmick gimmick creative creative accounting accounting trick trick balance balance budget budget house house republican republican say say introduction introduction fiscal fiscal budget budget true true budget budget rely rely gimmick gimmick budget budget gimmick gimmick pretend pretend keep keep strict strict limit limit defense defense spending spending called called sequestration sequestration pump pump ten ten billion billion extra extra dollar dollar slush slush fund fund called called overseas overseas contingency contingency operation operation mean mean fund fund count count emergency emergency spending spending part part pentagon pentagon budget budget assumes assumes current current tax tax cut cut allowed allowed expire expire scheduled scheduled would would amount amount billion billion tax tax increase increase nobody nobody belief belief would would allowed allowed go go effect effect proposes proposes repeal repeal obamacare obamacare count count revenue revenue saving saving obamacare obamacare law law remained remained effect effect claim claim save save trillion trillion year year fine fine print print budget budget plan plan instruction instruction committee committee asks asks identify identify billion billion saving saving time time assumes assumes trillion trillion cut cut category category known known mandatory mandatory program program specify specify cut cut would would relies relies billion billion additional additional revenue revenue dynamic dynamic scoring scoring generous generous accounting accounting method method account account billion billion plan plan negotiated negotiated increase increase doctor doctor payment payment medicare medicare extend extend child child health health care care program program difficulty difficulty concealing concealing sleight sleight hand hand might might explain explain price price hurry hurry leave leave news news conference conference tuesday tuesday predecessor predecessor rep rep paul paul ryan ryan r r wi wi liked liked give give lengthy lengthy seminar seminar conservative conservative budgeting budgeting theory theory price price took took question question six six minute minute aide aide hollered hollered last last question question chairman chairman gone gone minute minute later later reporter reporter gave gave chase chase leprechaun leprechaun budget budget pas pas one one asked asked think think price price said said locating locating confidence confidence sure sure absolutely absolutely latest latest instance instance republican republican discovering discovering difficult difficult govern govern unified unified control control congress congress past past four four year year budget budget debut debut academic academic exercise exercise would would never never agreement agreement republican republican house house democratic democratic senate senate budget budget might might actually actually mean mean something something firebrand firebrand elected elected pa ...
# Prediction: REAL (p=0.50)
# 	 + Sample: identity isi isi terrorist terrorist known known jihadi jihadi john john reportedly reportedly revealed revealed true true identity identity isi isi terrorist terrorist known known jihadi jihadi john john appeared appeared several several video video showing showing beheading beheading hostage hostage reportedly reportedly revealed revealed washington washington post post first first reported reported thursday thursday citing citing friend friend human human right right worker worker familiar familiar case case man man real real name name mohammed mohammed emwazi emwazi west west london london man man detained detained counterterror counterterror official official britain britain least least two two u u government government source source spoke spoke reuters reuters thursday thursday said said investigator investigator believe believe man man emwazi emwazi according according washington washington post post bbc bbc emwazi emwazi born born kuwait kuwait studied studied computer computer programming programming university university westminster westminster university university confirmed confirmed student student name name graduated graduated allegation allegation true true shocked shocked sickened sickened news news university university said said statement statement emwazi emwazi also also thought thought traveled traveled syria syria sometime sometime around around bbc bbc reported reported british british intelligence intelligence previously previously identified identified man man chosen chosen disclose disclose name name operational operational reason reason commander commander richard richard walton walton london london metropolitan metropolitan police police counter counter terrorism terrorism command command released released statement statement saying saying previously previously asked asked medium medium outlet outlet speculate speculate detail detail investigation investigation basis basis life life risk risk going going confirm confirm identity identity anyone anyone stage stage give give update update progress progress live live counter counter terrorism terrorism investigation investigation london london based based cage cage work work muslim muslim conflict conflict british british intelligence intelligence service service said said thursday thursday research research director director asim asim qureshi qureshi saw saw strong strong similarity similarity emwazi emwazi jihadi jihadi john john hood hood worn worn militant militant way way could could percent percent certain certain center center study study radicalization radicalization political political violence violence king king college college london london closely closely track track fighter fighter syria syria also also said said believed believed identification identification correct correct masked masked hooded hooded terrorist terrorist achieved achieved instant instant notoriety notoriety appeared appeared video video released released isi isi last last august august showed showed beheading beheading american american journalist journalist james james foley foley time time many many commentator commentator analyst analyst remarked remarked man man distinct distinct london london accent accent man man believed believed appeared appeared video video showed showed beheading beheading hostage hostage including including american american journalist journalist steven steven sotloff sotloff british british aid aid worker worker david david haines haines british british taxi taxi driver driver alan alan henning henning american american aid aid worker worker peter peter kassig kassig known known abdul abdul rahman rahman apparent apparent conversion conversion islam islam captivity captivity man man recent recent appearance appearance came came last last month month video video japanese japanese hostage hostage kenji kenji goto goto haruna haruna yukawa yukawa men men also also killed killed terror terror group group terrorist terrorist given given ...
# ------------------------------
